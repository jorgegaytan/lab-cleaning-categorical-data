# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
customer_df = pd.read_csv('files_for_lab/we_fn_use_c_marketing_customer_value_analysis.csv')

# %% [markdown]
# Find all of the categorical data. Save it in a categorical_df variable.

# %%
categorical_df = customer_df.select_dtypes(include=object)

# %%
categorical_df.head(30)
# Out:
#    Customer       State Response  Coverage             Education  \
# 0   BU79786  Washington       No     Basic              Bachelor
# 1   QZ44356     Arizona       No  Extended              Bachelor
# 2   AI49188      Nevada       No   Premium              Bachelor
# 3   WW63253  California       No     Basic              Bachelor
# 4   HB64268  Washington       No     Basic              Bachelor
# 5   OC83172      Oregon      Yes     Basic              Bachelor
# 6   XZ87318      Oregon      Yes     Basic               College
# 7   CF85061     Arizona       No   Premium                Master
# 8   DY87989      Oregon      Yes     Basic              Bachelor
# 9   BQ94931      Oregon       No  Extended               College
# 10  SX51350  California       No     Basic               College
# 11  VQ65197  California       No     Basic               College
# 12  DP39365  California       No   Premium                Master
# ...

# %% [markdown]
# Check for NaN values.

# %%
categorical_df.isna().sum()
# Out:
# Customer             0
# State                0
# Response             0
# Coverage             0
# Education            0
# Effective To Date    0
# EmploymentStatus     0
# Gender               0
# Location Code        0
# Marital Status       0
# Policy Type          0
# Policy               0
# Renew Offer Type     0
# Sales Channel        0
# Vehicle Class        0
# Vehicle Size         0
# dtype: int64

# %% [markdown]
# Check all unique values of columns.

# %%
for column in categorical_df:
    display(categorical_df[column].value_counts(dropna = False))
# Out:
# BU79786    1
# PU81096    1
# CO75086    1
# WW52683    1
# XO38850    1
#           ..
# HS14476    1
# YL91587    1
# CT18212    1
# EW35231    1
# Y167826    1
# Name: Customer, Length: 9134, dtype: int64
# California    3150
# Oregon        2601
# Arizona       1703
# Nevada         882
# Washington     798
# Name: State, dtype: int64
# No     7826
# Yes    1308
# Name: Response, dtype: int64
# Basic       5568
# Extended    2742
# Premium      824
# Name: Coverage, dtype: int64
# Bachelor                2748
# College                 2681
# High School or Below    2622
# Master                   741
# Doctor                   342
# Name: Education, dtype: int64
# 1/10/11    195
# 1/27/11    194
# 2/14/11    186
# 1/26/11    181
# 1/17/11    180
# 1/19/11    179
# 1/31/11    178
# 1/3/11     178
# 1/20/11    173
# 2/26/11    169
# 1/28/11    169
# 2/19/11    168
# 1/5/11     167
# 2/27/11    167
# 1/11/11    166
# 2/4/11     164
# 2/10/11    161
# 2/28/11    161
# 1/2/11     160
# ...

# %% [markdown]
# Check dtypes. Do they all make sense as categorical data?

# %%
categorical_df.dtypes
# Out:
# Customer             object
# State                object
# Response             object
# Coverage             object
# Education            object
# Effective To Date    object
# EmploymentStatus     object
# Gender               object
# Location Code        object
# Marital Status       object
# Policy Type          object
# Policy               object
# Renew Offer Type     object
# Sales Channel        object
# Vehicle Class        object
# Vehicle Size         object
# dtype: object

# %% [markdown]
# Column Effective To Date has values as dates it is not useful as categorical data

# %% [markdown]
# Does any column contain alpha and numeric data? Decide how to clean it.

# %% [markdown]
# As we did in the numerical lab, we can transform effective to date to datetime

# %% [markdown]
# Would you choose to do anything else to clean or wrangle the categorical data? Comment your decisions.

# %% [markdown]
# Compare policy_type and policy. What information is contained in these columns. Can you identify what is important?

# %% [markdown]
# 'Policy' and 'Policy Type' both specify whether an insurance is 'Personal', 'Corporate', or 'Special'. The important part is to figure out what is L1,L2...

# %% [markdown]
# Check number of unique values in each column, can they be combined in any way to ease encoding? Comment your thoughts and make those changes.

# %%
for column in categorical_df:
    print(column, len(categorical_df[column].value_counts()))
# Out:
# Customer 9134
# State 5
# Response 2
# Coverage 3
# Education 5
# Effective To Date 59
# EmploymentStatus 5
# Gender 2
# Location Code 3
# Marital Status 3
# Policy Type 3
# Policy 9
# Renew Offer Type 4
# Sales Channel 4
# Vehicle Class 6
# Vehicle Size 3

# %% [markdown]
# column 'customer' can be dropped because they are unique values
# as said earlier. effective to date can be either transformed or if it is not needed dropped
